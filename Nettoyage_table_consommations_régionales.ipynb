# %% [markdown]
# <a href="https://colab.research.google.com/github/Cecile31410/ecommerce-template/blob/main/Nettoyage_table_consommations_r%C3%A9gionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import plotly.express as px
# !gdown 1XSg04onQd_esyxUdA3gYCIF0dCeXgVoI
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XSg04onQd_esyxUdA3gYCIF0dCeXgVoI
# From (redirected): https://drive.google.com/uc?id=1XSg04onQd_esyxUdA3gYCIF0dCeXgVoI&confirm=t&uuid=5c3a433b-727c-4e70-a785-ab1078d8295e
# To: /content/eco2mix-regional-cons-def.csv
# 100% 320M/320M [00:01<00:00, 174MB/s]

# %%
conso2_df=pd.read_csv("eco2mix-regional-cons-def.csv", sep=";")
conso2_df.head()
# Out:
# <ipython-input-2-d1e3658c4347>:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   conso2_df=pd.read_csv("eco2mix-regional-cons-def.csv", sep=";")
#    Code INSEE région                      Région               Nature  \
# 0                 27     Bourgogne-Franche-Comté  Données définitives
# 1                 84        Auvergne-Rhône-Alpes  Données définitives
# 2                 93  Provence-Alpes-Côte d'Azur  Données définitives
# 3                 76                   Occitanie  Données définitives
# 4                 44                   Grand Est  Données définitives
#
#          Date  Heure               Date - Heure  Consommation (MW)  \
# 0  2013-01-01  00:00  2013-01-01T00:00:00+01:00                NaN
# 1  2013-01-01  00:00  2013-01-01T00:00:00+01:00                NaN
# 2  2013-01-01  00:00  2013-01-01T00:00:00+01:00                NaN
# 3  2013-01-01  00:00  2013-01-01T00:00:00+01:00                NaN
# ...

# %%
conso2_df.tail()
# Out:
#          Code INSEE région                      Région               Nature  \
# 2121403                 53                    Bretagne  Données consolidées
# 2121404                 84        Auvergne-Rhône-Alpes  Données consolidées
# 2121405                 27     Bourgogne-Franche-Comté  Données consolidées
# 2121406                 93  Provence-Alpes-Côte d'Azur  Données consolidées
# 2121407                 52            Pays de la Loire  Données consolidées
#
#                Date  Heure               Date - Heure  Consommation (MW)  \
# 2121403  2023-01-31  23:30  2023-01-31T23:30:00+01:00             3266.0
# 2121404  2023-01-31  23:30  2023-01-31T23:30:00+01:00             8927.0
# 2121405  2023-01-31  23:30  2023-01-31T23:30:00+01:00             2687.0
# 2121406  2023-01-31  23:30  2023-01-31T23:30:00+01:00             6139.0
# 2121407  2023-01-31  23:30  2023-01-31T23:30:00+01:00             3826.0
#
# ...

# %%
conso2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121408 entries, 0 to 2121407
# Data columns (total 32 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Code INSEE région    int64
#  1   Région               object
#  2   Nature               object
#  3   Date                 object
#  4   Heure                object
#  5   Date - Heure         object
#  6   Consommation (MW)    float64
#  7   Thermique (MW)       float64
#  8   Nucléaire (MW)       float64
#  9   Eolien (MW)          object
#  10  Solaire (MW)         float64
#  11  Hydraulique (MW)     float64
#  12  Pompage (MW)         float64
#  13  Bioénergies (MW)     float64
#  14  Ech. physiques (MW)  float64
#  15  Stockage batterie    float64
#  16  Déstockage batterie  float64
#  17  Eolien terrestre     float64
#  18  Eolien offshore      float64
#  19  TCO Thermique (%)    float64
#  20  TCH Thermique (%)    float64
#  21  TCO Nucléaire (%)    float64
# ...

# %%
conso2_df["Région"].unique()
# Out:
# array(['Bourgogne-Franche-Comté', 'Auvergne-Rhône-Alpes',
#        "Provence-Alpes-Côte d'Azur", 'Occitanie', 'Grand Est',
#        'Normandie', 'Bretagne', 'Île-de-France', 'Pays de la Loire',
#        'Nouvelle-Aquitaine', 'Centre-Val de Loire', 'Hauts-de-France'],
#       dtype=object)

# %%
# Calcul du nombre de valeurs nulles par colonne
null_counts = conso2_df.isnull().sum()
print("\nNombre de valeurs nulles par colonne :")
print(null_counts)
# Out:
# Nombre de valeurs nulles par colonne :
# Code INSEE région            0
# Région                       0
# Nature                       0
# Date                         0
# Heure                        0
# Date - Heure                 0
# Consommation (MW)           12
# Thermique (MW)              12
# Nucléaire (MW)          701287
# Eolien (MW)                  0
# Solaire (MW)                12
# Hydraulique (MW)            12
# Pompage (MW)            736327
# Bioénergies (MW)            12
# Ech. physiques (MW)         12
# Stockage batterie      1683084
# Déstockage batterie    1683084
# Eolien terrestre       1683084
# Eolien offshore        1683084
# TCO Thermique (%)      1472256
# TCH Thermique (%)      1472256
# TCO Nucléaire (%)      1560096
# TCH Nucléaire (%)      1742736
# TCO Eolien (%)         1472256
# TCH Eolien (%)         1472256
# TCO Solaire (%)        1472256
# TCH Solaire (%)        1472256
# TCO Hydraulique (%)    1472256
# TCH Hydraulique (%)    1472256
# ...

# %%
# Attempt to convert to numeric, non-numeric values will become NaN
conso2_df['numeric_column'] = pd.to_numeric(conso2_df["Eolien (MW)"], errors='coerce')

# Identify non-numeric values
non_numeric_values = conso2_df[conso2_df['numeric_column'].isna()]["Eolien (MW)"]

# Print non-numeric values
print("Valeurs non numériques dans la colonne 'Eolien':")
print(non_numeric_values)
print(non_numeric_values.unique())
# Out:
# Valeurs non numériques dans la colonne 'Eolien':
# 0         ND
# 1         ND
# 2         ND
# 3         ND
# 4         ND
#           ..
# 207895     -
# 207910     -
# 207918     -
# 207928     -
# 207940     -
# Name: Eolien (MW), Length: 108, dtype: object
# ['ND' '-']

# %%
# Remplacer "ND" et "-" par des chaînes vides dans la colonne "Eolien (MW)"
conso2_df["Eolien (MW)"].replace(["ND", "-"], "", inplace=True)

# %%
conso2_df["Eolien (MW)"] = pd.to_numeric(conso2_df["Eolien (MW)"], errors='coerce')

# %%
conso2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121408 entries, 0 to 2121407
# Data columns (total 33 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Code INSEE région    int64
#  1   Région               object
#  2   Nature               object
#  3   Date                 object
#  4   Heure                object
#  5   Date - Heure         object
#  6   Consommation (MW)    float64
#  7   Thermique (MW)       float64
#  8   Nucléaire (MW)       float64
#  9   Eolien (MW)          float64
#  10  Solaire (MW)         float64
#  11  Hydraulique (MW)     float64
#  12  Pompage (MW)         float64
#  13  Bioénergies (MW)     float64
#  14  Ech. physiques (MW)  float64
#  15  Stockage batterie    float64
#  16  Déstockage batterie  float64
#  17  Eolien terrestre     float64
#  18  Eolien offshore      float64
#  19  TCO Thermique (%)    float64
#  20  TCH Thermique (%)    float64
#  21  TCO Nucléaire (%)    float64
# ...

# %%
conso2_df['Date - Heure'] = pd.to_datetime(conso2_df['Date - Heure'], errors='coerce')
print(conso2_df['Date - Heure'].dtype)
# Out:
# datetime64[ns, UTC+01:00]

# %%
conso2_df['time_bins'] = conso2_df['Date - Heure'].dt.floor('2h')
grouped_conso2h_df=conso2_df.groupby(['time_bins', 'Région'])[['Consommation (MW)', 'Thermique (MW)', 'Nucléaire (MW)', 'Eolien (MW)', 'Solaire (MW)', 'Hydraulique (MW)', 'Bioénergies (MW)']].sum().reset_index()
grouped_conso2h_df.head()
# Out:
#                   time_bins                   Région  Consommation (MW)  \
# 0 2013-01-01 00:00:00+01:00     Auvergne-Rhône-Alpes            24013.0
# 1 2013-01-01 00:00:00+01:00  Bourgogne-Franche-Comté             6972.0
# 2 2013-01-01 00:00:00+01:00                 Bretagne             8651.0
# 3 2013-01-01 00:00:00+01:00      Centre-Val de Loire             7355.0
# 4 2013-01-01 00:00:00+01:00                Grand Est            14594.0
#
#    Thermique (MW)  Nucléaire (MW)  Eolien (MW)  Solaire (MW)  \
# 0           756.0         36192.0        761.0           0.0
# 1           705.0             0.0        315.0           0.0
# 2           174.0             0.0        344.0           0.0
# 3           270.0         27504.0       1545.0           0.0
# 4           958.0         27221.0       3389.0           0.0
#
#    Hydraulique (MW)  Bioénergies (MW)
# 0            8617.0             200.0
# 1             315.0              38.0
# 2             446.0              60.0
# ...

# %%
grouped_conso2h_df.tail()
# Out:
#                        time_bins                      Région  \
# 222907 2023-01-31 22:00:00+01:00          Nouvelle-Aquitaine
# 222908 2023-01-31 22:00:00+01:00                   Occitanie
# 222909 2023-01-31 22:00:00+01:00            Pays de la Loire
# 222910 2023-01-31 22:00:00+01:00  Provence-Alpes-Côte d'Azur
# 222911 2023-01-31 22:00:00+01:00               Île-de-France
#
#         Consommation (MW)  Thermique (MW)  Nucléaire (MW)  Eolien (MW)  \
# 222907            23506.0           628.0         14774.0        189.0
# 222908            22468.0           316.0          4934.0       3090.0
# 222909            15041.0           685.0             0.0        802.0
# 222910            24020.0          1230.0             0.0        154.0
# 222911            38675.0          1525.0             0.0        244.0
#
#         Solaire (MW)  Hydraulique (MW)  Bioénergies (MW)
# 222907           0.0            1451.0             451.0
# ...

# %%
grouped_conso2h_df.to_csv("Conso_région_group2h.csv", index=False)

# %%
import os

file_size = os.path.getsize('/content/Conso_région_group2h.csv')
print("file size :", file_size, "bytes")
# Out:
# file size : 19232172 bytes
